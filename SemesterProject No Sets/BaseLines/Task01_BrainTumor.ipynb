# %%
from fastMONAI.vision_all import *

from monai.apps import DecathlonDataset
from sklearn.model_selection import train_test_split
import pandas as pd
# Out:
# C:\Users\Eirik\anaconda3\envs\raskmonai\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (None)/charset_normalizer (3.1.0) doesn't match a supported version!
#   warnings.warn(

# %%
path = Path('..\data')
path.mkdir(exist_ok=True)

# %%
BrainTumorSet = DecathlonDataset(root_dir=path, task="Task01_BrainTumour", section="training", download=False,
                                 cache_num=0, num_workers=3)

# %%
df = pd.DataFrame(BrainTumorSet.data)

# %%
df.head()
# Out:
#                                                   image  \
# 0  ..\data\Task01_BrainTumour\imagesTr\BRATS_442.nii.gz
# 1  ..\data\Task01_BrainTumour\imagesTr\BRATS_389.nii.gz
# 2  ..\data\Task01_BrainTumour\imagesTr\BRATS_380.nii.gz
# 3  ..\data\Task01_BrainTumour\imagesTr\BRATS_245.nii.gz
# 4  ..\data\Task01_BrainTumour\imagesTr\BRATS_453.nii.gz
#
#                                                   label
# 0  ..\data\Task01_BrainTumour\labelsTr\BRATS_442.nii.gz
# 1  ..\data\Task01_BrainTumour\labelsTr\BRATS_389.nii.gz
# 2  ..\data\Task01_BrainTumour\labelsTr\BRATS_380.nii.gz
# 3  ..\data\Task01_BrainTumour\labelsTr\BRATS_245.nii.gz
# 4  ..\data\Task01_BrainTumour\labelsTr\BRATS_453.nii.gz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   388 non-null    object
#  1   label   388 non-null    object
# dtypes: object(2)
# memory usage: 6.2+ KB

# %%
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)
train_df.shape, test_df.shape
# Out:
# ((349, 2), (39, 2))

# %%
med_dataset = MedDataset(img_list=train_df.label.tolist()[:20], dtype=MedMask, max_workers=12)

# %%
med_dataset.df.head()
# Out:
#                                                    path  dim_0  dim_1  dim_2  \
# 0  ..\data\Task01_BrainTumour\labelsTr\BRATS_477.nii.gz    240    240    155
# 1  ..\data\Task01_BrainTumour\labelsTr\BRATS_350.nii.gz    240    240    155
# 2  ..\data\Task01_BrainTumour\labelsTr\BRATS_266.nii.gz    240    240    155
# 3  ..\data\Task01_BrainTumour\labelsTr\BRATS_294.nii.gz    240    240    155
# 4  ..\data\Task01_BrainTumour\labelsTr\BRATS_466.nii.gz    240    240    155
#
#    voxel_0  voxel_1  voxel_2 orientation  voxel_count_0  voxel_count_1  \
# 0      1.0      1.0      1.0        RAS+        8765377          83088
# 1      1.0      1.0      1.0        RAS+        8872636          21364
# 2      1.0      1.0      1.0        RAS+        8725071          83276
# 3      1.0      1.0      1.0        RAS+        8790699          90806
# 4      1.0      1.0      1.0        RAS+        8911252          14046
#
#    voxel_count_2  voxel_count_3
# 0          15826          63709
# 1           8872          25128
# 2          69784          49869
# 3          20231          26264
# 4             60           2642

# %%
summary_df = med_dataset.summary()

# %%
summary_df
# Out:
#    dim_0  dim_1  dim_2  voxel_0  voxel_1  voxel_2 orientation  \
# 0    240    240    155      1.0      1.0      1.0        RAS+
#
#                                            example_path  total
# 0  ..\data\Task01_BrainTumour\labelsTr\BRATS_009.nii.gz     20

# %%
resample, reorder = med_dataset.suggestion()
resample, reorder
# Out:
# ([1.0, 1.0, 1.0], False)

# %%
img_size = med_dataset.get_largest_img_size(resample=resample)
img_size
# Out:
# [240.0, 240.0, 155.0]

# %%
item_tfms = [ZNormalization(), PadOrCrop([240,240,160]), RandomAffine(scales=0, degrees=5, isotropic=True)]

# %%
dblock = MedDataBlock(blocks=(ImageBlock(cls=MedImage), MedMaskBlock), 
                      splitter=RandomSplitter(seed=42),
                      get_x=ColReader('image'),
                      get_y=ColReader('label'),
                      item_tfms=item_tfms,
                      batch_tfms=None,
                      reorder=reorder,
                      resample=resample)

# %%
bs=2
dls = dblock.dataloaders(train_df, bs=bs)

# %%
dls.show_batch(anatomical_plane=0, unique=True)

# %%
len(dls.train_ds.items), len(dls.valid_ds.items)
# Out:
# (280, 69)

# %%
from monai.networks.nets import UNet
from monai.losses import DiceCELoss

# %%
codes = np.unique(med_img_reader(train_df.label.tolist()[0]))
n_classes = len(codes)

# %%
codes, n_classes
# Out:
# (array([0., 1., 2., 3.], dtype=float32), 4)

# %%
model = UNet(dimensions=3, in_channels=4, out_channels=n_classes, 
             channels=(16, 32, 64, 128, 256),strides=(2, 2, 2, 2), 
             num_res_units=2)
# Out:
# C:\Users\Eirik\anaconda3\envs\raskmonai\lib\site-packages\monai\utils\deprecate_utils.py:219: FutureWarning: monai.networks.nets.unet UNet.__init__:dimensions: Argument `dimensions` has been deprecated since version 0.6. Please use `spatial_dims` instead.
#   warn_deprecated(argname, msg, warning_category)

# %%
loss_func = CustomLoss(loss_func=DiceCELoss(to_onehot_y=True, include_background=True, softmax=True))

# %%
learn = Learner(dls, model, loss_func=loss_func, opt_func=ranger, metrics=multi_dice_score)

# %%
lr = learn.lr_find()#.to_fp16()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
epochs = 4

# %%
learn.fit_flat_cos(epochs, lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>multi_dice_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.032966</td>
#       <td>0.711706</td>
#       <td>tensor([0.4654, 0.0134, 0.2122])</td>
#       <td>09:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.591313</td>
#       <td>0.535255</td>
#       <td>tensor([0.6080, 0.0007, 0.4740])</td>
#       <td>09:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.477657</td>
#       <td>0.420517</td>
#       <td>tensor([0.6475, 0.3737, 0.5594])</td>
#       <td>08:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.376003</td>
#       <td>0.364166</td>
#       <td>tensor([0.6689, 0.4388, 0.6566])</td>
#       <td>08:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('baseline.braintumor-model')
# Out:
# Path('models/baseline.braintumor-model.pth')

# %%
learn.show_results(anatomical_plane=0, ds_idx=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
test_dl = learn.dls.test_dl(test_df,with_labels=True)

# %%
test_dl.show_batch(anatomical_plane=0, figsize=(15,15))

# %%
pred_acts, labels = learn.get_preds(dl=test_dl)
pred_acts.shape, labels.shape
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (torch.Size([39, 4, 240, 240, 160]), torch.Size([39, 1, 240, 240, 160]))

# %%
multi_dice_score(pred_acts, labels)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 multi_dice_score(pred_acts, labels)
#
# File ~\anaconda3\envs\raskmonai\lib\site-packages\fastMONAI\vision_metrics.py:43, in multi_dice_score(act, targ)
#      37 def multi_dice_score(act, # Activation values [B, C, W, H, D]
#      38                      targ # Target masks [B, C, W, H, D]
#      39                     ) -> torch.Tensor:
#      40     '''Calculate the mean Dice score for each class in multi-class semantic segmentation tasks.'''
# ---> 43     pred, n_classes = batch_pred_to_multiclass_mask(act)
#      44     binary_dice_scores = []
#      46     for c in range(1, n_classes):
#
# File ~\anaconda3\envs\raskmonai\lib\site-packages\fastMONAI\vision_data.py:32, in batch_pred_to_multiclass_mask(pred)
#      29 n_classes = pred.shape[1]
#      30 pred = [pred_to_multiclass_mask(p) for p in pred]
# ---> 32 return torch.stack(pred), n_classes
#
# RuntimeError: [enforce fail at C:\cb\pytorch_1000000000000\work\c10\core\impl\alloc_cpu.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 2875392000 bytes.

# %%
learn.show_results(anatomical_plane=0, dl=test_dl, ds_idx=19)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export('baseline_braintumor_model.pkl')
