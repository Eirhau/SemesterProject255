# %%
from fastMONAI.vision_all import *

from monai.apps import DecathlonDataset
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
path = Path('..\data')
path.mkdir(exist_ok=True)

# %%
HepaticVesselSet = DecathlonDataset(root_dir=path, task="Task08_HepaticVessel", section="training", download=False,
                                 cache_num=0, num_workers=3)

# %%
df = pd.DataFrame(HepaticVesselSet.data)

# %%
df.head()
# Out:
#                                                             image  \
# 0  ..\data\Task08_HepaticVessel\imagesTr\hepaticvessel_132.nii.gz
# 1  ..\data\Task08_HepaticVessel\imagesTr\hepaticvessel_111.nii.gz
# 2  ..\data\Task08_HepaticVessel\imagesTr\hepaticvessel_221.nii.gz
# 3  ..\data\Task08_HepaticVessel\imagesTr\hepaticvessel_094.nii.gz
# 4  ..\data\Task08_HepaticVessel\imagesTr\hepaticvessel_446.nii.gz
#
#                                                             label
# 0  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_132.nii.gz
# 1  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_111.nii.gz
# 2  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_221.nii.gz
# 3  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_094.nii.gz
# 4  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_446.nii.gz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   243 non-null    object
#  1   label   243 non-null    object
# dtypes: object(2)
# memory usage: 3.9+ KB

# %%
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)
train_df.shape, test_df.shape
# Out:
# ((218, 2), (25, 2))

# %%
med_dataset = MedDataset(img_list=train_df.label.tolist()[:20], dtype=MedMask, max_workers=12)

# %%
med_dataset.df.head()
# Out:
#                                                              path  dim_0  \
# 0  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_286.nii.gz    512
# 1  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_030.nii.gz    512
# 2  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_007.nii.gz    512
# 3  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_423.nii.gz    512
# 4  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_214.nii.gz    512
#
#    dim_1  dim_2  voxel_0  voxel_1  voxel_2 orientation  voxel_count_0  \
# 0    512    164   0.7891   0.7891      1.5        RAS+       42956243
# 1    512     39   0.9492   0.9492      5.0        RAS+       10193584
# 2    512     50   0.8945   0.8945      5.0        RAS+       12925378
# 3    512     27   0.8613   0.8613      7.5        RAS+        7060000
# 4    512     99   0.8594   0.8594      2.5        RAS+       25918297
#
#    voxel_count_1  voxel_count_2
# 0          34919            454
# 1          11906          18126
# 2          12520         169302
# 3          10081           7807
# 4          27924           6035

# %%
summary_df = med_dataset.summary()

# %%
summary_df
# Out:
#     dim_0  dim_1  dim_2  voxel_0  voxel_1  voxel_2 orientation  \
# 18    512    512    164   0.7891   0.7891      1.5        RAS+
# 10    512    512     50   0.8945   0.8945      5.0        RAS+
# 17    512    512    141   0.6836   0.6836      1.5        RAS+
# 16    512    512    121   0.8105   0.8105      1.5        RAS+
# 15    512    512    105   0.8066   0.8066      2.5        RAS+
# 14    512    512     99   0.8984   0.8984      2.5        RAS+
# 13    512    512     99   0.8594   0.8594      2.5        RAS+
# 12    512    512     80   0.7227   0.7227      2.5        RAS+
# 11    512    512     63   0.9766   0.9766      5.0        RAS+
# 0     512    512     24   0.6797   0.6797      7.5        RAS+
# 1     512    512     27   0.8613   0.8613      7.5        RAS+
# 8     512    512     49   0.8125   0.8125      5.0        RAS+
# 7     512    512     45   0.9766   0.9766      5.0        RAS+
# 6     512    512     45   0.8184   0.8184      5.0        RAS+
# 5     512    512     42   0.8008   0.8008      5.0        RAS+
# 4     512    512     42   0.7031   0.7031      5.0        RAS+
# 3     512    512     39   0.9492   0.9492      5.0        RAS+
# 2     512    512     36   0.9355   0.9355      5.0        RAS+
# 9     512    512     49   0.9004   0.9004      5.0        RAS+
#
#                                                       example_path  total
# 18  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_286.nii.gz      2
# 10  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_007.nii.gz      1
# 17  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_340.nii.gz      1
# 16  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_172.nii.gz      1
# 15  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_173.nii.gz      1
# 14  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_223.nii.gz      1
# 13  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_214.nii.gz      1
# 12  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_373.nii.gz      1
# 11  ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_262.nii.gz      1
# 0   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_248.nii.gz      1
# 1   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_423.nii.gz      1
# 8   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_027.nii.gz      1
# 7   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_080.nii.gz      1
# 6   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_290.nii.gz      1
# 5   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_061.nii.gz      1
# 4   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_386.nii.gz      1
# 3   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_030.nii.gz      1
# 2   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_092.nii.gz      1
# 9   ..\data\Task08_HepaticVessel\labelsTr\hepaticvessel_408.nii.gz      1

# %%
resample, reorder = med_dataset.suggestion()
resample, reorder
# Out:
# ([0.7891, 0.7891, 5.0], False)

# %%
img_size = med_dataset.get_largest_img_size(resample=resample)
img_size
# Out:
# [634.0, 634.0, 63.0]

# %%
item_tfms = [ZNormalization(), PadOrCrop([512,512,80]), RandomAffine(scales=0, degrees=5, isotropic=True)]

# %%
dblock = MedDataBlock(blocks=(ImageBlock(cls=MedImage), MedMaskBlock), 
                      splitter=RandomSplitter(seed=42),
                      get_x=ColReader('image'),
                      get_y=ColReader('label'),
                      item_tfms=item_tfms,
                      batch_tfms=None,
                      reorder=reorder,
                      resample=resample)

# %%
bs=1
dls = dblock.dataloaders(train_df, bs=bs)

# %%
dls.show_batch(anatomical_plane=0, unique=True)

# %%
len(dls.train_ds.items), len(dls.valid_ds.items)
# Out:
# (175, 43)

# %%
from monai.networks.nets import UNet
from monai.losses import DiceCELoss

# %%
codes = np.unique(med_img_reader(train_df.label.tolist()[0]))
n_classes = len(codes)

# %%
codes, n_classes
# Out:
# (array([0., 1., 2.], dtype=float32), 3)

# %%
model = UNet(dimensions=3, in_channels=1, out_channels=n_classes, 
             channels=(16, 32, 64, 128, 256),strides=(2, 2, 2, 2), 
             num_res_units=2)
# Out:
# C:\Users\Eirik\anaconda3\envs\raskmonai\lib\site-packages\monai\utils\deprecate_utils.py:219: FutureWarning: monai.networks.nets.unet UNet.__init__:dimensions: Argument `dimensions` has been deprecated since version 0.6. Please use `spatial_dims` instead.
#   warn_deprecated(argname, msg, warning_category)

# %%
loss_func = CustomLoss(loss_func=DiceCELoss(to_onehot_y=True, include_background=True, softmax=True))

# %%
learn = Learner(dls, model, loss_func=loss_func, opt_func=ranger, metrics=multi_dice_score)

# %%
lr = learn.lr_find()#.to_fp16()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
epochs = 4

# %%
learn.fit_flat_cos(epochs, lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>multi_dice_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.746399</td>
#       <td>0.684954</td>
#       <td>tensor([0., 0.])</td>
#       <td>08:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.685785</td>
#       <td>0.680405</td>
#       <td>tensor([0., 0.])</td>
#       <td>08:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.677577</td>
#       <td>0.675217</td>
#       <td>tensor([0., 0.])</td>
#       <td>08:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.670568</td>
#       <td>0.673103</td>
#       <td>tensor([0., 0.])</td>
#       <td>08:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('baseline.hepaticvessel-model')
# Out:
# Path('models/baseline.hepaticvessel-model.pth')

# %%
learn.show_results(anatomical_plane=0, ds_idx=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
test_dl = learn.dls.test_dl(test_df,with_labels=True)

# %%
test_dl.show_batch(anatomical_plane=0, figsize=(15,15))

# %%
pred_acts, labels = learn.get_preds(dl=test_dl)
pred_acts.shape, labels.shape
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (torch.Size([25, 3, 512, 512, 80]), torch.Size([25, 1, 512, 512, 80]))

# %%
multi_dice_score(pred_acts, labels)
# Out:
# tensor([0., 0.])

# %%
learn.show_results(anatomical_plane=0, dl=test_dl, ds_idx=19)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export('baseline_hepaticvessel_model.pkl')
